# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.1.3
# 1.20.2

# %% [markdown]
# Persiapan DataFrame

# %%
n_rows = 365 * 24
n_cols = 2
cols = ['col1', 'col2']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)),
                 columns=cols)

df.index = pd.util.testing.makeDateIndex(n_rows, freq='H')
df
# Out:
#                      col1  col2
# 2000-01-01 00:00:00     6     8
# 2000-01-01 01:00:00     6    14
# 2000-01-01 02:00:00     4    10
# 2000-01-01 03:00:00    10     4
# 2000-01-01 04:00:00     8     9
# ...                   ...   ...
# 2000-12-30 19:00:00    14    18
# 2000-12-30 20:00:00    10    15
# 2000-12-30 21:00:00     7    10
# 2000-12-30 22:00:00    11    14
# 2000-12-30 23:00:00    10    12
#
# [8760 rows x 2 columns]

# %% [markdown]
# Resampling data dengan interval monthly

# %%
df.resample('M')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-31  7234
# 2000-02-29  6812
# 2000-03-31  7634
# 2000-04-30  7271
# 2000-05-31  7380
# 2000-06-30  7259
# 2000-07-31  7404
# 2000-08-31  7431
# 2000-09-30  6983
# 2000-10-31  7469
# 2000-11-30  7372
# 2000-12-31  7232

# %% [markdown]
# Resample data dengan interval daily

# %%
df.resample('D')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-01   213
# 2000-01-02   239
# 2000-01-03   286
# 2000-01-04   190
# 2000-01-05   273
# ...          ...
# 2000-12-26   218
# 2000-12-27   207
# 2000-12-28   271
# 2000-12-29   247
# 2000-12-30   220
#
# [365 rows x 1 columns]
